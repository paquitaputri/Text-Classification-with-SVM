# %% [markdown]
# Here we will perform Text Classification on the Instagram caption Using Support Vector Machine algorithm and also by using the TF-IDF method.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import SVC
import pickle
from sklearn.externals import joblib
import re
# Out:
# C:\Users\Paquita\miniconda3\envs\jcop_ud\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
train=pd.read_csv('woytrain.csv')
train
# Out:
#                 username                                            caption  \
# 0            rajvegad055   viral  top  instatop  public  photography  ed...
# 1            flexkulture   fashion  fashionista  streetstyle  streetwear...
# 2               ishovonn   insta  instagram  travelgram  travel  instahu...
# 3         thesundayclub_  tas  taswanita  tascewek  tasimport  tasmurah ...
# 4              ay_mumtaz   bajumuslim  style  fashion  atasan  bajuatasa...
# ...                  ...                                                ...
# 66166  macon_travel_easy   macay  luxuryvacationrentals  workwiththebest...
# 66167      yogabudiman94               holiday  pulaupramuka  pramukaisland
# 66168     plasatravel.id      tiketmurah  travel  plasatravel  paketliburan
# 66169    frise_invaligia   ulivet  pugli  carovign  ital  iamt  travelre...
# 66170          blawi_art   hdr  sunset  nature  river  fishing  fun  l  ...
#
#        labelling
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 66166          5
# 66167          5
# 66168          5
# 66169          5
# 66170          5
#
# [66171 rows x 3 columns]

# %%
train['labelling'] = train['labelling'].map({1 : 'Fashion',
                                    2 : 'Food & Beverage',
                                    3 : 'Technology',
                                    4 : 'Health & Beauty',
                                    5 : 'Lifestyle & Travel'})

# %%
# remove special characters, numbers, punctuations
train['caption'] = train['caption'].str.replace("[^a-zA-Z#]", " ")

#Remove double/multiple space
train['caption'] = train['caption'].apply(lambda x: ' '.join(str(x).split()))

#lowercase word
train['caption'] = train['caption'].apply(lambda x: x.lower())

#remove emoticon
def Emoticon_clean(text):
    regrex_pattern = re.compile(pattern = "["
                    u"\U0001F600-\U0001F64F"  # emoticons
                    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                    u"\U0001F1F2-\U0001F1F4"  # Macau flag
                    u"\U0001F1E6-\U0001F1FF"  # flags
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

train['caption'] = train['caption'].apply(lambda x: Emoticon_clean(x))

# %%
train.head(50)
# Out:
#                      username  \
# 0                 rajvegad055
# 1                 flexkulture
# 2                    ishovonn
# 3              thesundayclub_
# 4                   ay_mumtaz
# 5                 hausofkochi
# 6   p.carmila_putrinovianti99
# 7                     mfadli0
# 8                   mithra.us
# 9             beautytips.blog
# 10                     ciwiku
# 11                      _myn4
# 12           pearls_of_islamm
# 13               belanjacraft
# 14                  theegrisy
# 15           selena1gomez1992
# 16                 masako0831
# 17               anis_savitri
# 18      blackkpinksinyourarea
# 19                 viastrozzi
# 20             alivekapratama
# 21              omorfamatiaid
# 22                     riau92
# 23              ahmadhalawa__
# 24                 aksya_aprn
# 25             customcarszone
# 26              ellenoor_love
# 27                  yonesaris
# 28          colorfulgirl_iran
# 29               andreigorlov
# 30               saqata_shop1
# 31              sakinahh_shan
# 32               hitboxstudio
# 33                    cktegar
# 34             accu_sihombing
# 35             __salar_._hi__
# 36                cocolime_us
# 37           kultprit.apparel
# 38                  rdtbomber
# 39                     im.hg9
# 40              kawan_hijrahh
# 41               vania_johana
# 42          ririninayah_store
# 43               putudharma03
# 44                   svetl044
# 45                  mithra.us
# 46                jolly__joke
# 47        love_life_ane_locha
# 48            trinity_totebag
# 49                    bimsurr
#
#                                               caption labelling
# 0   viral top instatop public photography editz po...   Fashion
# 1   fashion fashionista streetstyle streetwearfash...   Fashion
# 2   insta instagram travelgram travel instahub ins...   Fashion
# 3   tas taswanita tascewek tasimport tasmurah tasm...   Fashion
# 4   bajumuslim style fashion atasan bajuatasan rok...   Fashion
# 5   fashion dubaifashion dolceandgabbana fashionav...   Fashion
# 6   olahraga style selebgram folow folow hunting p...   Fashion
# 7   like like followersindonesia visitsumut medan ...   Fashion
# 8   mithra mensfashion fashion style menstyle ootd...   Fashion
# 9   dewiroesdji dewiqu fotos fashionblog fashionde...   Fashion
# 10  ubud monkeyforest elephantcave bali wonderful ...   Fashion
# 11  love tagsforlikes instagood tweegram photoofth...   Fashion
# 12  muslimcouple themodestymovement hijabfashion h...   Fashion
# 13  belanjacraft handstitching fabric craft sue bi...   Fashion
# 14  theegrisy theegrisyreborn kaos kaostheegrisy h...   Fashion
# 15  love followback instagramers socialenvy please...   Fashion
# 16  mohipilates machinepilates pilates pilates fas...   Fashion
# 17  mywedding nikahbarokah anice bepe menikah gant...   Fashion
# 18  blackpink jisoo lisa jennie ros jenniesolo lov...   Fashion
# 19  chicagolandmark cityofchicago armitage linconl...   Fashion
# 20  likes ootdfashion follower prilaga inspiring i...   Fashion
# 21  omorfamatia bag slingbag handbag totebag taspr...   Fashion
# 22  like like instapict instaphoto instagood love ...   Fashion
# 23  ahmed beautysalon hairstylist hairdresser phot...   Fashion
# 24  selfie selfienation toptags selfies instahub m...   Fashion
# 25  cars car tarvel customcar custom fashion calif...   Fashion
# 26  bat set paris gamis black polka tartans paris ...   Fashion
# 27  followback instagramers envywear tweegram phot...   Fashion
# 28  springsummer fashion fashionnova fashionblogge...   Fashion
# 29  itunes applemusic music electronic lightstorm ...   Fashion
# 30  hotd hijablove instamoda thehijabstyle hijabsw...   Fashion
# 31  fashionblogger photographylife photooftheday p...   Fashion
# 32  music mood today blessed inspiration motivatio...   Fashion
# 33  fashion fashionillustration sketchbook fashion...   Fashion
# 34  fotostudio fotografer foto pose fashionista wh...   Fashion
# 35  muscle fashion streetstyle offwhite beautiful ...   Fashion
# 36  sportswear fitness fashion sport workout activ...   Fashion
# 37  kultprit fashion fashionista denims jeans styl...   Fashion
# 38  jaket jaketbombermurah jaketbomber jaketcewek ...   Fashion
# 39  latepost saturday blessed night photoshoot pho...   Fashion
# 40  gamis hijab tunik gamismurah gamissyari dress ...   Fashion
# 41  april latepost grateful mazmur latepost annive...   Fashion
# 42  ahha kaosahha attahalilintar longsleeve kaospa...   Fashion
# 43  makeupideas makeup makeupnatural makeuptutoria...   Fashion
# 44        design beautiful style mytager com interior   Fashion
# 45  fashion hat swag streetwear snapbackmurah cap ...   Fashion
# 46  view landscape sun enjoy landscapelovers stree...   Fashion
# 47  love tflers tweegram photooftheday likes amazi...   Fashion
# 48  totebag totebagmurah tas totebagcustom olshop ...   Fashion
# 49  dailylife dailyessentials essentials vscogood ...   Fashion

# %%
caption = train['caption']

# %% [markdown]
# ### Count The Value of TF-IDF

# %%
count_vect = CountVectorizer()
caption_count = count_vect.fit_transform(caption)
tfidf = TfidfTransformer()
tfidf_caption = tfidf.fit_transform(caption_count)

# %%
#get the feature names
feature_names = count_vect.get_feature_names()

#get tfidf vector for first document
first_document_vector=tfidf_caption[0]

#print the scores
df = pd.DataFrame(first_document_vector.T.todense(), index=feature_names, columns=["tfidf"])
df = df.sort_values(by=["tfidf"],ascending=False)
df.head(10)
# Out:
#                tfidf
# editz       0.386787
# instatop    0.381003
# actorslife  0.316553
# public      0.313772
# attitude    0.288668
# bollywood   0.272849
# pose        0.262660
# models      0.244513
# top         0.241793
# hairstyle   0.240630

# %%
count_vect.vocabulary_
# Out:
# {'viral': 92833,
#  'top': 88450,
#  'instatop': 40107,
#  'public': 71506,
#  'photography': 68526,
#  'editz': 22718,
#  'pose': 70262,
#  'models': 58106,
#  'look': 51779,
#  'attitude': 4244,
#  'style': 83283,
#  'bollywood': 10679,
#  'actorslife': 427,
#  'hairstyle': 33145,
#  'fashion': 25515,
#  'fashionista': 25675,
#  'streetstyle': 83078,
#  'streetwearfashion': 83103,
#  'streetwear': 83097,
#  'hype': 36837,
#  'hypebeast': 36842,
#  'highfashion': 34901,
#  'offwhite': 63523,
#  'supreme': 84308,
#  'bape': 6525,
#  'balenciaga': 5845,
#  'louisvuitton': 51967,
#  'gucci': 32574,
#  'yeezy': 96706,
#  'lit': 51151,
#  'fire': 26629,
#  'drip': 21777,
#  'trending': 89802,
#  'trend': 89798,
#  'trendy': 89822,
#  'trendsetter': 89820,
#  'fashionblogger': 25559,
#  'streetstylefashion': 83080,
#  'culture': 18345,
#  'sneakers': 80769,
#  'insta': 39304,
#  'instagram': 39618,
#  'travelgram': 89254,
#  'travel': 89059,
#  'instahub': 39735,
#  'instacool': 39432,
#  'instagramhub': 39650,
#  'nature': 61021,
#  'landscape': 49141,
#  'landscapephotography': 49154,
#  'naturephotography': 61065,
#  'natureporn': 61073,
#  'ourplanetdaily': 64928,
#  'streetphotography': 83022,
#  'natureaddict': 61023,
#  'naturelovers': 61052,
#  'earth': 22341,
#  'travelphotography': 89559,
#  'traveling': 89293,
#  'travelblogger': 89123,
#  'vsco': 93449,
#  'vscofilter': 93476,
#  'vscocam': 93460,
#  'canonphotographer': 13331,
#  'rainforest': 72453,
#  'cairns': 12766,
#  'australia': 4319,
#  'worl': 96173,
#  'tas': 85630,
#  'taswanita': 85899,
#  'tascewek': 85675,
#  'tasimport': 85724,
#  'tasmurah': 85787,
#  'tasmurahjakarta': 85792,
#  'dompet': 21274,
#  'dompetcewek': 21278,
#  'dompetwanita': 21303,
#  'dompetmurah': 21297,
#  'dompetimport': 21285,
#  'ootd': 64272,
#  'handbag': 33406,
#  'handbagwanita': 33411,
#  'handbagmurah': 33408,
#  'handbagcewek': 33407,
#  'bajumuslim': 5481,
#  'atasan': 4118,
#  'bajuatasan': 5322,
#  'rokmuslim': 74630,
#  'skirt': 80125,
#  'bajumurah': 5471,
#  'bajugamis': 5387,
#  'gamissyari': 29770,
#  'kulotmuslim': 48452,
#  'gamispesta': 29737,
#  'grosirbaju': 32387,
#  'jaket': 41502,
#  'dress': 21654,
#  'bajutunik': 5599,
#  'tunik': 90378,
#  'sepatu': 77796,
#  'sweater': 84630,
#  'pesta': 68151,
#  'pasmina': 66410,
#  'hijab': 34969,
#  'jilbabsyari': 42632,
#  'muslimah': 59962,
#  'batikcouple': 6940,
#  'nafishop': 60498,
#  'dubaifashion': 22036,
#  'dolceandgabbana': 21229,
#  'fashionavenue': 25538,
#  'dubaimall': 22052,
#  'jewels': 42523,
#  'floral': 27195,
#  'feminine': 26182,
#  'colorful': 16688,
#  'crowns': 18117,
#  'flowers': 27275,
#  'designers': 19905,
#  'fashiondesigners': 25593,
#  'dubaidesigner': 22031,
#  'dubaistylist': 22064,
#  'olahraga': 63659,
#  'selebgram': 77375,
#  'folow': 27590,
#  'hunting': 36697,
#  'photoshoot': 68703,
#  'senimanmudaberkarya': 77702,
#  'talent': 85226,
#  'model': 58008,
#  'purwakartahits': 71916,
#  'purwakarta': 71914,
#  'internasional': 40298,
#  'situbuleud': 79765,
#  'alunalunpurwakarta': 1974,
#  'like': 50634,
#  'likeforlike': 50688,
#  'likeforfollow': 50677,
#  'modelpurwakarta': 58105,
#  'followersindonesia': 27504,
#  'visitsumut': 93106,
#  'medan': 55978,
#  'weekend': 94555,
#  'mithra': 57763,
#  'mensfashion': 56557,
#  'menstyle': 56620,
#  'dapper': 19097,
#  'mensstyle': 56608,
#  'instafashion': 39501,
#  'men': 56415,
#  'gq': 31860,
#  'instagood': 39584,
#  'outfit': 65006,
#  'luxury': 52628,
#  'gentleman': 30344,
#  'love': 51982,
#  'streetfashion': 82934,
#  'menwithclass': 56734,
#  'menwithstyle': 56739,
#  'stylish': 83371,
#  'lifestyle': 50498,
#  'picoftheday': 68878,
#  'photooftheday': 68641,
#  'swag': 84587,
#  'bespoke': 8612,
#  'dewiroesdji': 20153,
#  'dewiqu': 20152,
#  'fotos': 28433,
#  'fashionblog': 25556,
#  'fashiondesigner': 25590,
#  'fashionmagazines': 25711,
#  'fashionaddicted': 25525,
#  'fashionable': 25517,
#  'muslimfashion': 59990,
#  'muslimahwear': 59979,
#  'fotography': 28368,
#  'jogjahits': 42839,
#  'jogjakarta': 42859,
#  'batikjogja': 6957,
#  'bloggerstyle': 10087,
#  'blogger': 10057,
#  'media': 56027,
#  'magazine': 53023,
#  'fashionstreet': 25795,
#  'hssilver': 36492,
#  'ujyuna': 90855,
#  'jewerly': 42525,
#  'shoes': 78873,
#  'ubud': 90713,
#  'monkeyforest': 58443,
#  'elephantcave': 23035,
#  'bali': 5854,
#  'wonderful': 95866,
#  'indonesia': 38345,
#  'travelogue': 89525,
#  'holiday': 35734,
#  'vacation': 91738,
#  'withdrawal': 95598,
#  'happygirl': 33682,
#  'tagsforlikes': 85046,
#  'tweegram': 90568,
#  'lfl': 50236,
#  'fff': 26304,
#  'instamood': 39863,
#  'me': 55893,
#  'cute': 18580,
#  'igers': 37283,
#  'summer': 83750,
#  'tbt': 85997,
#  'instadaily': 39445,
#  'smkn': 80504,
#  'banyuwangi': 6509,
#  'bestoftheday': 8738,
#  'sky': 80153,
#  'webstagram': 94298,
#  'picstitch': 68901,
#  'nofilter': 62359,
#  'happy': 33621,
#  'instagramers': 39637,
#  'muslimcouple': 59989,
#  'themodestymovement': 87340,
#  'hijabfashion': 35048,
#  'hijabers': 35031,
#  'hijablove': 35114,
#  'hijabi': 35065,
#  'hijabchic': 35002,
#  'hijabchamber': 35001,
#  'hijabtutorial': 35222,
#  'hijabstyle': 35189,
#  'hijabmurah': 35130,
#  'hijabblogger': 34994,
#  'hijabvideo': 35226,
#  'hijabbeauty': 34992,
#  'hijabqueen': 35156,
#  'hijabfashionista': 35049,
#  'hijabstyleicon': 35193,
#  'chichijab': 14946,
#  'simplycovered': 79490,
#  'muslimahfashion': 59966,
#  'hfupclose': 34824,
#  'hijabvogue': 35229,
#  'hijabmuslim': 35135,
#  'tesettur': 86733,
#  'dailyhijab': 18840,
#  'hijabsolo': 35181,
#  'turc': 90423,
#  'belanjacraft': 8138,
#  'handstitching': 33526,
#  'fabric': 25015,
#  'craft': 17723,
#  'sue': 83478,
#  'billy': 9324,
#  'kriya': 47806,
#  'patchwork': 66569,
#  'japanese': 41872,
#  'jahit': 41242,
#  'kain': 44394,
#  'yarndyed': 96654,
#  'jualan': 43155,
#  'online': 64130,
#  'order': 64593,
#  'customized': 18556,
#  'purse': 71899,
#  'bag': 5176,
#  'handmade': 33452,
#  'coinpurse': 16532,
#  'keychain': 46311,
#  'quilting': 72196,
#  'handquilting': 33499,
#  'keypurse': 46313,
#  'theegrisy': 87185,
#  'theegrisyreborn': 87188,
#  'kaos': 44742,
#  'kaostheegrisy': 44914,
#  'hoodie': 36099,
#  'hoodietheegrisy': 36113,
#  'sweatertheegrisy': 84655,
#  'kaosku': 44855,
#  'kaosdistro': 44786,
#  'cottoncombed': 17531,
#  'clothing': 16139,
#  'indonesiansclothing': 38518,
#  'kaoskeren': 44850,
#  'kaosgokil': 44800,
#  'kaosadem': 44743,
#  'followback': 27484,
#  'socialenvy': 80931,
#  'pleaseforgiveme': 69650,
#  'likes': 50767,
#  'amazing': 2076,
#  'smile': 80471,
#  'follow': 27476,
#  'instalike': 39793,
#  'food': 27611,
#  'instafollow': 39527,
#  'followme': 27542,
#  'girl': 30769,
#  'socialenvyco': 80932,
#  'mohipilates': 58223,
#  'machinepilates': 52794,
#  'pilates': 69046,
#  'japanesefashion': 41887,
#  'sports': 82034,
#  'mywedding': 60449,
#  'nikahbarokah': 62053,
#  'anice': 2826,
#  'bepe': 8381,
#  'menikah': 56496,
#  'gantistatus': 29831,
#  'istrisholehah': 40749,
#  'wife': 95157,
#  'glowing': 31128,
#  'keren': 46067,
#  'loveit': 52099,
#  'pernikahanindonesia': 67904,
#  'pernikahanimpian': 67902,
#  'pernikahanmuslim': 67909,
#  'pernikahanku': 67906,
#  'wedding': 94311,
#  'weddingparty': 94458,
#  'halal': 33209,
#  'sah': 75464,
#  'pacarhalalku': 65188,
#  'blackpink': 9889,
#  'jisoo': 42675,
#  'lisa': 51121,
#  'jennie': 42383,
#  'ros': 74801,
#  'jenniesolo': 42386,
#  'beautiful': 7480,
#  'solo': 81126,
#  'selfie': 77453,
#  'kpopf': 47628,
#  'art': 3606,
#  'friends': 28859,
#  'kpopfff': 47630,
#  'likeforlikes': 50696,
#  'followforfollowbacks': 27519,
#  'chicagolandmark': 14937,
#  'cityofchicago': 15834,
#  'armitage': 3538,
#  'linconlparkchicago': 50869,
#  'chicagoboutique': 14926,
#  'womensfashion': 95821,
#  'instalove': 39810,
#  'lovestyle': 52249,
#  'lovechicago': 52019,
#  'italianboutique': 40777,
#  'lincolnparkshopping': 50868,
#  'shoparmitage': 78947,
#  'influenser': 38769,
#  'lovefashion': 52045,
#  'chicagogram': 14934,
#  'italianlook': 40797,
#  'trendreport': 89818,
#  'fashionfix': 25615,
#  'summerstyle': 83817,
#  'springstyle': 82151,
#  'summerinchicago': 83789,
#  'lincolnpark': 50866,
#  'ootdfashion': 64298,
#  'follower': 27495,
#  'prilaga': 70915,
#  'inspiring': 39290,
#  'ootdmagazine': 64348,
#  'followforfollow': 27516,
#  'inspiringquotes': 39291,
#  'ootdmen': 64353,
#  'shot': 79036,
#  'followforfollowback': 27517,
#  'entrepreneur': 23573,
#  'followers': 27498,
#  'ootdshare': 64380,
#  'entrepreneurship': 23588,
#  'entrepreneurs': 23587,
#  'entrepreneurlife': 23581,
#  'omorfamatia': 64000,
#  'slingbag': 80307,
#  'totebag': 88611,
#  'tasprinting': 85815,
#  'travelling': 89423,
#  'localbrandid': 51417,
#  'madeinindonesia': 52882,
#  'instapict': 39962,
#  'instaphoto': 39946,
#  'girls': 30803,
#  'nails': 60543,
#  'hair': 33040,
#  'beauty': 7586,
#  'pretty': 70796,
#  'girly': 30881,
#  'pink': 69160,
#  'eyes': 24969,
#  'heels': 34469,
#  'styles': 83350,
#  'ahmed': 1079,
#  'beautysalon': 7769,
#  'hairstylist': 33153,
#  'hairdresser': 33093,
#  'hairlook': 33113,
#  'hairdo': 33079,
#  'newlook': 61573,
#  'haircare': 33049,
#  'haircut': 33073,
#  'haircolor': 33064,
#  'stunning': 83266,
#  'bride': 11409,
#  'gorgeous': 31729,
#  'specialnight': 81802,
#  'bridetobe': 11434,
#  'selfienation': 77469,
#  'toptags': 88542,
#  'selfies': 77475,
#  'queenselfie': 72155,
#  'handsome': 33509,
#  'instaselfie': 40024,
#  'selfietime': 77480,
#  'bestselfiepics': 8790,
#  'shamelessselefie': 78552,
#  'selfieaddict': 77454,
#  'selfiegram': 77464,
#  'thehub': 87266,
#  'portraits': 70222,
#  'portrait': 70188,
#  'kings': 46694,
#  'igdaily': 37269,
#  'selfieoftheday': 77471,
#  'best': 8619,
#  'expression': 24840,
#  'face': 25033,
#  'cars': 13677,
#  'car': 13503,
#  'tarvel': 85626,
#  'customcar': 18534,
#  'custom': 18526,
#  'california': 12881,
#  'newyork': 61663,
#  'washington': 94007,
#  'usa': 91562,
#  'ford': 28140,
#  'volkswagen': 93391,
#  'gmc': 31227,
#  'cadillac': 12678,
#  'bat': 6854,
#  'set': 78180,
#  'paris': 66139,
#  'gamis': 29618,
#  'black': 9758,
#  'polka': 69917,
#  'tartans': 85611,
#  'viscose': 92884,
#  'lace': 48784,
#  'kaftan': 44354,
#  'kebaya': 45424,
#  'dobiset': 21087,
#  'batik': 6924,
#  'ellenoor': 23081,
#  'original': 64732,
#  'woman': 95698,
#  'envywear': 23620,
#  'boy': 11090,
#  'envywearco': 23621,
#  'springsummer': 82152,
#  'fashionnova': 25743,
#  'idea': 37089,
#  'beautyblogger': 7603,
#  'persiangirl': 67937,
#  'lookoftheday': 51817,
#  'colorfulgirl': 16690,
#  'iran': 40531,
#  'itunes': 40902,
#  'applemusic': 3219,
#  'music': 59880,
#  'electronic': 22987,
#  'lightstorm': 50615,
#  'apple': 3213,
#  'newmusic': 61581,
#  'new': 61484,
#  'high': 34884,
#  'andreigorlov': 2702,
#  'sound': 81533,
#  'ios': 40441,
#  'time': 87908,
#  'regress': 73340,
#  'spotify': 82087,
#  'fun': 29177,
#  'hotd': 36243,
#  'instamoda': 39855,
#  'thehijabstyle': 87254,
#  'hijabswag': 35199,
#  'hijabcandy': 34998,
#  'modestclothing': 58159,
#  'hidjabstore': 34863,
#  'hijablife': 35110,
#  'hijabmodesty': 35123,
#  'hidjabootd': 34862,
#  'modesty': 58167,
#  'hidjabindonesia': 34861,
#  'fashionhijabis': 25647,
#  'hijabspiration': 35182,
#  'hijabilookbook': 35068,
#  'hijabdaily': 35008,
#  'hijabistyle': 35084,
#  'moda': 57973,
#  'jualhijab': 43470,
#  'hijaboftheday': 35140,
#  'fashionmodesty': 25722,
#  'photographylife': 68551,
#  'photographer': 68485,
#  'plannergirl': 69509,
#  'explorejogja': 24549,
#  'jogja': 42803,
#  'jogjaistimewa': 42852,
#  'wisatajogja': 95434,
#  'wonderfulindonesia': 95884,
#  'jogjaku': 42866,
#  'pesonaindonesia': 68102,
#  'visitjogja': 93009,
#  'quotesoftheday': 72248,
#  'mood': 58548,
#  'today': 88169,
#  'blessed': 9974,
#  'inspiration': 39265,
#  'motivation': 58829,
#  'djs': 21032,
#  'latina': 49464,
#  'artists': 3707,
#  'vocalist': 93329,
#  'songwriters': 81341,
#  'vocals': 93332,
#  'nevergiveup': 61465,
#  'fashionillustration': 25659,
#  'sketchbook': 79863,
#  'fashionsketches': 25787,
#  'fashionsketch': 25786,
#  'illustration': 37706,
#  'fashiondrawing': 25602,
#  'sketch': 79860,
#  'fashionart': 25533,
#  'fashiondesign': 25589,
#  'sketching': 79869,
#  'fashionsketching': 25788,
#  'fashionillustrators': 25661,
#  'artistsoninstagram': 3710,
#  'artist': 3690,
#  'artwork': 3780,
#  'drawing': 21583,
#  'draw': 21576,
#  'fashiondraw': 25601,
#  'illustrator': 37717,
#  'fotostudio': 28440,
#  'fotografer': 28328,
#  'foto': 28298,
#  'whiteonwhite': 95056,
#  'matalensa': 55606,
#  'crown': 18113,
#  'action': 392,
#  'patunglilin': 66625,
#  'beludrupremium': 8269,
#  'matamerahpicture': 55609,
#  'glowingskin': 31138,
#  'mehronmakeup': 56160,
#  'muscle': 59802,
#  'nice': 61903,
#  'gym': 32868,
#  'wow': 96292,
#  'lovely': 52125,
#  'gymnastics': 32914,
#  'catwalk': 14009,
#  'instagra': 39613,
#  'sportswear': 82065,
#  'fitness': 26836,
#  'sport': 82008,
#  'workout': 96114,
#  'activewear': 413,
#  'nike': 62057,
#  'gymwear': 32933,
#  'yoga': 96826,
#  'fitnessmotivation': 26899,
#  'leggings': 49839,
#  'apparel': 3192,
#  'fit': 26751,
#  'yogawear': 96904,
#  'fitnesswear': 26923,
#  'london': 51633,
#  'adidas': 510,
#  'running': 75170,
#  'sportbra': 82016,
#  'sporty': 82076,
#  'fitnessmodel': 26895,
#  'fitfam': 26780,
#  'bhfyp': 8982,
#  'kultprit': 48455,
#  'denims': 19724,
#  'jeans': 42223,
#  'street': 82884,
#  'menswear': 56629,
#  'instapic': 39957,
#  'instalook': 39808,
#  'oootdmen': 64265,
#  'lotd': 51930,
#  'potd': 70382,
#  'jaketbombermurah': 41512,
#  'jaketbomber': 41510,
#  'jaketcewek': 41515,
#  'jaketcewekmurah': 41516,
#  'bandung': 6214,
#  'bandungfashion': 6250,
#  'fashionhijab': 25644,
#  'jakarta': 41400,
#  'jakartashop': 41477,
#  'jaketbomberanak': 41511,
#  'latepost': 49440,
#  'saturday': 76475,
#  'night': 61972,
#  'asian': 3880,
#  'beard': 7406,
#  'man': 54600,
#  'football': 28095,
#  'training': 88928,
#  'cool': 17260,
#  'life': 50390,
#  'healthy': 34246,
#  'enjoy': 23467,
#  'moment': 58283,
#  'yolo': 96984,
#  'gamismurah': 29695,
#  'syari': 84850,
#  'kulot': 48446,
#  'blouse': 10154,
#  'baju': 5305,
#  'jilbab': 42568,
#  'tunikmurah': 90392,
#  'gamiscantik': 29649,
#  'gamisanak': 29624,
#  'celana': 14121,
#  'mukena': 59585,
#  'dressmurah': 21700,
#  'hijabsyari': 35201,
#  'olshopmurah': 63890,
#  'bajukoko': 5425,
#  'hijabmurahbanget': 35132,
#  'april': 3247,
#  'grateful': 32065,
#  'mazmur': 55813,
#  'anniversary': 2924,
#  'happyfirst': 33676,
#  'pslam': 71439,
#  'thankful': 86972,
#  'joy': 43082,
#  'hope': 36140,
#  'flower': 27242,
#  'roses': 74820,
#  'journey': 43061,
#  'relationshipgoals': 73397,
#  'red': 73130,
#  'dining': 20625,
#  'dinner': 20631,
#  'ahha': 1065,
#  'kaosahha': 44744,
#  'attahalilintar': 4237,
#  'longsleeve': 51748,
#  'kaospanjang': 44880,
#  'kaospanjangcowok': 44881,
#  'sun': 83851,
#  'baby': 4870,
#  'photo': 68374,
#  'makeupideas': 53875,
#  'makeup': 53626,
#  'makeupnatural': 53999,
#  'makeuptutorial': 54183,
#  'makeupparty': 54032,
#  'makeupunik': 54190,
#  'makeupblog': 53732,
#  'likeforlikeback': 50691,
#  'likelike': 50723,
#  'diy': 20953,
#  'diycrafts': 20958,
#  'diycraft': 20957,
#  'makeuplife': 53947,
#  'tutorialmakeupnatural': 90526,
#  'rainbow': 72436,
#  'design': 19886,
#  'mytager': 60406,
#  'com': 16778,
#  'interior': 40267,
#  'hat': 33978,
#  'snapbackmurah': 80701,
#  'cap': 13420,
#  'newera': 61537,
#  'hiphop': 35395,
#  'snapbackimport': 80700,
#  'dope': 21414,
#  'skate': 79812,
#  'hats': 33999,
#  'repost': 73636,
#  'tattoo': 85944,
#  'caps': 13459,
#  'snapchat': 80704,
#  'skateboarding': 79818,
#  'view': 92647,
#  'landscapelovers': 49149,
#  'germany': 30452,
#  'sunny': 83999,
#  'trip': 89929,
#  'instamoment': 39860,
#  'ig': 37236,
#  'relax': 73405,
#  'park': 66196,
#  'panorama': 65786,
#  'badenbaden': 5115,
#  'tflers': 86874,
#  'iphoneonly': 40486,
#  'instago': 39579,
#  'all': 1692,
#  'shots': 79066,
#  'totebagmurah': 88617,
#  'totebagcustom': 88612,
#  'olshop': 63832,
#  'sydney': 84862,
#  'opera': 64466,
#  'dailylife': 18856,
#  'dailyessentials': 18825,
#  'essentials': 23896,
#  'vscogood': 93483,
#  'vibesnature': 92435,
#  'visualsoflife': 93189,
#  'createexplore': 17883,
#  'thecreatorclass': 87154,
#  'igmasters': 37437,
#  'minimal': 57502,
#  'minimalist': 57514,
#  'minimalmovement': 57525,
#  'vibes': 92434,
#  'hypebeastxvsco': 36846,
#  'streetdreamsmag': 82928,
#  'mobile': 57896,
#  'samsung': 75974,
#  'highsnobiety': 34942,
#  'kinfolk': 46666,
#  'livefolk': 51242,
#  'goodshot': 31605,
#  'gramoftheday': 31940,
#  'awesomeminimal': 4537,
#  'cozy': 17696,
#  'muslim': 59961,
#  'islam': 40643,
#  'quran': 72262,
#  'allah': 1701,
#  'hijrah': 35250,
#  'islamic': 40649,
#  'slamnah': 80215,
#  'islamicquotes': 40656,
#  'dakwah': 18919,
#  'ikuti': 37643,
#  'dua': 22011,
#  'tauhid': 85957,
#  'pemudahijrah': 67188,
#  'de': 19375,
#  'pembaca': 67094,
#  'ustadzabdulsomad': 91643,
#  'prayer': 70609,
#  'hadith': 33014,
#  'converseoriginal': 17175,
#  'converseoriginalsecond': 17176,
#  'conversehigh': 17171,
#  'converselover': 17173,
#  'sepatumurah': 77905,
#  'sepatubekas': 77819,
#  'sneakersurban': 80793,
#  'urbanstyle': 91524,
#  'vansoriginal': 91888,
#  'vansoldskool': 91887,
#  'vanssecondoriginal': 91890,
#  'vanssecond': 91889,
#  'vanssk': 91891,
#  'hi': 34829,
#  'istimewa': 40737,
#  'tasbatam': 85654,
#  'pouch': 70434,
#  'tasbranded': 85668,
#  'tassekolah': 85835,
#  'taskerja': 85752,
#  'taskuliah': 85756,
#  'tasanak': 85632,
#  'ranse': 72709,
#  'imuzindonesia': 38025,
#  'imuz': 38024,
#  'official': 63493,
#  'imuzreadytowear': 38027,
#  'readytowear': 72948,
#  'batiknusantara': 6975,
#  'batikindonesia': 6952,
#  'batikcowok': 6941,
#  'motiftruntum': 58807,
#  'batiksolo': 6991,
#  'designerbatik': 19896,
#  'designersurabaya': 19907,
#  'fashionlifestyle': 25701,
#  'fashionpria': 25764,
#  'boboiboy': 10400,
#  'boboiboygalaxy': 10401,
#  'boboiboyoriginals': 10402,
#  'boboiboythemovie': 10403,
#  'yogalove': 96868,
#  'igyogi': 37529,
#  'health': 34187,
#  'eatclean': 22448,
#  'breatheandsmile': 11338,
#  'mikeandmore': 57269,
#  'yogapur': 96892,
#  'shredded': 79113,
#  'hashtags': 33962,
#  'diet': 20339,
#  'lift': 50543,
#  'determination': 20042,
#  'bodybuilding': 10449,
#  'cardio': 13572,
#  'girlswholift': 30856,
#  'kacamata': 44243,
#  'kacamatamurah': 44271,
#  'kacamataminus': 44270,
#  'kacamatafashion': 44250,
#  'kacamatacewek': 44248,
#  'glasses': 31006,
#  'kacamatagaya': 44252,
#  'jualanku': 43187,
#  'murah': 59753,
#  'kacamatabranded': 44247,
#  'berniaga': 8562,
#  'kacamatacowok': 44249,
#  'mataminus': 55611,
#  'jualkacamata': 43516,
#  'sunglasses': 83964,
#  'kacamatawanita': 44281,
#  'mata': 55588,
#  'kacamatakorea': 44268,
#  'kacamatakeren': 44267,
#  'kacamatavintage': 44280,
#  'kacamatabandung': 44246,
#  'clothes': 16132,
#  'trendyweek': 89830,
#  'shoponline': 78974,
#  'italy': 40818,
#  'negozio': 61295,
#  'tshirt': 90186,
#  'sweatshirt': 84663,
#  'negozioonline': 61296,
#  'abbigliamento': 59,
#  'donnaabbigliamento': 21338,
#  'jackets': 41018,
#  'antingfashion': 3023,
#  'olshopsda': 63909,
#  'olshopsidoarjo': 63913,
#  'trustolshop': 90155,
#  'earrings': 22334,
#  'earringsoftheday': 22336,
#  'antingmurah': 3032,
#  'antingmurahsidoarjo': 3033,
#  'antinghijab': 3028,
#  'iwearovashion': 40941,
#  'nichememe': 61942,
#  'nichememes': 61943,
#  'hamilton': 33345,
#  'dogsofinstagram': 21147,
#  'iceskating': 37039,
#  'billieeilish': 9316,
#  'arianagrande': 3472,
#  'bts': 11762,
#  'btsfanart': 11770,
#  'piercings': 68962,
#  'bulletjournal': 12141,
#  'womenfromvenus': 95777,
#  'ring': 74297,
#  'earring': 22328,
#  'ringoftheday': 74310,
#  'ringlove': 74307,
#  'galaxy': 29487,
#  'boho': 10592,
#  'bohemian': 10586,
#  'bohostyle': 10613,
#  'bohofashion': 10596,
#  'modern': 58128,
#  'pearllove': 66787,
#  'green': 32182,
#  'pictureoftheday': 68921,
#  'jewelry': 42506,
#  'jewelrydesigner': 42512,
#  'jewelrylover': 42516,
#  'friendship': 28865,
#  'workpartner': 96141,
#  'offduty': 63460,
#  'retail': 73932,
#  'casual': 13815,
#  'denim': 19709,
#  'jacket': 41007,
#  'padang': 65225,
#  'jawa': 42133,
#  'sunda': 83876,
#  'india': 38103,
#  'binekatunggalika': 9345,
#  'faboulous': 25014,
#  'flawless': 27092,
#  'outfitoftheday': 65029,
#  'parentingtips': 66098,
#  'parentingquotes': 66097,
#  'parenting': 66090,
#  'parentingblogger': 66092,
#  'momlife': 58318,
#  'parentinglife': 66096,
#  'parentinghumor': 66094,
#  'dressage': 21656,
#  'ootdindo': 64321,
#  'motherhood': 58778,
#  'parenthood': 66089,
#  'dresses': 21673,
#  'parentingislami': 66095,
#  'lgbt': 50263,
#  'gayfrance': 30061,
#  'inked': 39069,
#  'ink': 39065,
#  'gayfit': 30060,
#  'instagay': 39569,
#  'gay': 30038,
#  'awesome': 4520,
#  'fashionstyle': 25801,
#  'urban': 91450,
#  'blog': 10048,
#  'instaloo': 39807,
#  'peninggi': 67501,
#  'langsing': 49228,
#  'herbal': 34649,
#  'peninggibadan': 67503,
#  'peninggibadantiens': 67511,
#  'pelangsingtiens': 67021,
#  'ncp': 61206,
#  'zinc': 97484,
#  'kalsium': 44524,
#  'tinggibadan': 87979,
#  'tiens': 87817,
#  'obattiens': 63298,
#  'jualolshop': 43726,
#  'terbukti': 86655,
#  'abghits': 84,
#  'aceh': 270,
#  'gadiscantik': 29413,
#  'makasar': 53535,
#  'palembang': 65549,
#  'malang': 54337,
#  'morning': 58640,
#  'maroon': 55108,
#  'wellther': 94735,
#  'ontopoftheworld': 64248,
#  'moutain': 59017,
#  'altitude': 1953,
#  'hikingculture': 35290,
#  'hikinglife': 35300,
#  'hikingtrail': 35308,
#  'hikingtrip': 35309,
#  'bestviews': 8828,
#  'breathtakingviews': 11343,
#  'dontlookdown': 21363,
#  'epicviews': 23654,
#  'greatviews': 32155,
#  'instastyle': 40069,
#  'wackyboys': 93597,
#  'kte': 47839,
#  'taipei': 85113,
#  'naive': 60556,
#  'brave': 11254,
#  'dresstenun': 21724,
#  'dresskantor': 21689,
#  'bajukantor': 5414,
#  'dressformal': 21677,
#  'dresspesta': 21708,
#  'bajupesta': 5536,
#  'bajuwanita': 5601,
#  'dressbatik': 21665,
#  'bajubatik': 5338,
#  'tenunbagus': 86577,
#  'gaunpesta': 30026,
#  'gaun': 30011,
#  'dresstradisional': 21727,
#  'dressetnik': 21676,
#  'dresscantik': 21667,
#  'kaftancantik': 44360,
#  'womanfashion': 95710,
#  'cantik': 13359,
#  'moderndress': 58134,
#  'tenunmodern': 86595,
#  'batikmodernhttps': 6972,
#  'beys': 8942,
#  'collection': 16633,
#  'collections': 16635,
#  'html': 36500,
#  'gattinoni': 30007,
#  'glam': 30980,
#  'watch': 94030,
#  'watches': 94035,
#  'bags': 5215,
#  ...}

# %%
#Save countvectorizer to pickle
joblib.dump(count_vect, 'count_vec.pkl')

#save tfidftransformer to pickle
joblib.dump(tfidf, 'tfidf.pkl')
# Out:
# ['tfidf.pkl']

# %%
labels = train['labelling']
text = tfidf_caption
Train_X, Test_X, Train_Y, Test_Y = train_test_split(text,labels,test_size=0.3, stratify=labels, random_state=42)

svc_rbf = SVC()
svc_train_rbf = svc_rbf.fit(Train_X, Train_Y)
score_svc_rbf = (svc_train_rbf.score(Train_X, Train_Y) * 100)
print("Prediction score of Support Vector Classifier is {:.2f} %".format(score_svc_rbf))
# Out:
# Prediction score of Support Vector Classifier is 92.66 %

# %% [markdown]
# ### Prediction for Data Testing

# %%
# take Model SVM from pickle
joblib.dump(svc_rbf, 'model_svc.pkl')
# Out:
# ['model_svc.pkl']

# %%
svc_rbf_predict = svc_rbf.predict(Test_X)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# This F1-score can be used as a benchmark for evaluating classification results, when the class in the data has a class imbalance. This imbalanced class occurs if the ratio in each class is not proportional. The result will be showed in Classification report

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_score = (accuracy_score(Test_Y, svc_rbf_predict) * 100)
print(classification_report(Test_Y, svc_rbf_predict))
print("The result of Accuracy score of Data Testing is {:.2f} %".format(accuracy_score))
# Out:
#                     precision    recall  f1-score   support
#
#            Fashion       0.83      0.82      0.83      3792
#    Food & Beverage       0.92      0.87      0.90      2501
#    Health & Beauty       0.89      0.95      0.92      6845
# Lifestyle & Travel       0.90      0.87      0.89      6298
#         Technology       0.92      0.81      0.86       416
#
#           accuracy                           0.89     19852
#          macro avg       0.90      0.87      0.88     19852
#       weighted avg       0.89      0.89      0.89     19852
#
# The result of Accuracy score of Data Testing is 88.95 %
